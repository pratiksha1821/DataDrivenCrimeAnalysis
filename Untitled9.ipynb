# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# Importing the dataset
df = pd.read_csv("/content/Crime_Data_from_2020_to_Present122.csv")

# Checking the dimensions of the dataset
print(df.shape)

# Listing the columns of the dataset
print(df.columns)

# Viewing the first five rows of the dataset
print(df.head())

# Viewing the last five rows of the dataset
print(df.tail())

# Viewing all the information about the dataset
print(df.info())

# Descriptive statistics of the dataset
print(df.describe())

# Checking for missing values in the dataset and their total count
print(df.isnull().sum())

# Viewing the maximum values in the dataset
print(df.max(numeric_only=True))

# Viewing the minimum values in the dataset
print(df.min(numeric_only=True))

# Viewing the median values in the dataset
print(df.mean(numeric_only=True))

# Viewing the mean values in the dataset
print(df.median(numeric_only=True))

# Viewing the mode values in the dataset
print(df.mode())

# Counting non-null values in each column
print(df.count())

# Cleaning the dataset by dropping rows with missing values
df.dropna(inplace=True)

# Creating a numpy array from the crime rate
crime_code_array = np.array(df["Crm Cd"])
print(crime_code_array)

# Filtering years with crime data greater than 50
high_crime_years = df[df["Crm Cd"] > 50]
print(high_crime_years)

# Creating a histogram for the "Crm Cd" column
plt.hist(df["Crm Cd"], bins=10, color="blue", edgecolor="black")
plt.xlabel("Crime Code")
plt.ylabel("Frequency")
plt.title("Distribution of Crime Codes")
plt.show()

# Creating a bar chart to show the average crime code by area
avg_crime_code_by_area = df.groupby("AREA NAME")["Crm Cd"].mean()
avg_crime_code_by_area.plot(kind='bar', color='orange', figsize=(12, 6))
plt.xlabel("Area Name")
plt.ylabel("Average Crime Code")
plt.title("Crime Code by Area Name")
plt.show()

# Creating a line graph to show the trend of crime code across dates
plt.plot(df["DATE OCC"], df["Crm Cd"], marker='o')
plt.xlabel("Date of Occurrence")
plt.ylabel("Crime Code")
plt.title("Trend of Crime Code Across Dates")
plt.show()

# Scatter plot between 'Crm Cd' and 'Vict Age'
plt.scatter(df["Crm Cd"], df["Vict Age"], color='red')
plt.xlabel("Crime Code")
plt.ylabel("Victim Age")
plt.title("Crime Code vs Victim Age")
plt.show()

# Boxplot for "Crm Cd" distribution by year
sns.boxplot(x="Date Rptd", y="Crm Cd", data=df)
plt.title("Crime Code Distribution by Year")
plt.show()

# Creating a heatmap to visualize the correlation between features
numeric_df = df.select_dtypes(include=['number'])
numeric_df = numeric_df.dropna(axis=1, how='all')
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# Violin plot for crime code distribution by area
sns.violinplot(x="AREA NAME", y="Crm Cd", data=df)
plt.title("Crime Code by Area Name")
plt.show()


# Count plot for crime descriptions
sns.countplot(x="Crm Cd Desc", data=df)
plt.title("Count of Crime Descriptions")
plt.show()

# KDE plot for the distribution of crime codes
sns.kdeplot(df["Crm Cd"], shade=True)
plt.title("Distribution of Crime Codes")
plt.show()
# Out:
# (74773, 28)
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')
#        DR_NO         Date Rptd          DATE OCC  TIME OCC  AREA   AREA NAME  \
# 0  190326475  03-01-2020 00:00  03-01-2020 00:00      2130     7    Wilshire
# 1  200106753  02-09-2020 00:00  02-08-2020 00:00      1800     1     Central
# 2  200320258  11-11-2020 00:00  11-04-2020 00:00      1700     3   Southwest
# 3  200907217  05-10-2023 00:00  03-10-2020 00:00      2037     9    Van Nuys
# 4  200412582  09-09-2020 00:00  09-09-2020 00:00       630     4  Hollenbeck
#
#    Rpt Dist No  Part 1-2  Crm Cd                               Crm Cd Desc  \
# 0          784         1     510                          VEHICLE - STOLEN
# 1          182         1     330                     BURGLARY FROM VEHICLE
# 2          356         1     480                             BIKE - STOLEN
# 3          964         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4          413         1     510                          VEHICLE - STOLEN
#
#    ... Status   Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  ...     AA  Adult Arrest    510.0    998.0       NaN      NaN
# 1  ...     IC   Invest Cont    330.0    998.0       NaN      NaN
# 2  ...     IC   Invest Cont    480.0      NaN       NaN      NaN
# 3  ...     IC   Invest Cont    343.0      NaN       NaN      NaN
# 4  ...     IC   Invest Cont    510.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 2   1400 W  37TH                         ST          NaN  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                          200 E  AVENUE 28          NaN  34.0820 -118.2130
#
# [5 rows x 28 columns]
#            DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 74768  201007095        03-11-2020 00:00        03-10-2020 00:00      1600
# 74769  201105253  01/29/2020 12:00:00 AM  01/28/2020 12:00:00 AM       955
# 74770  200812344  07/27/2020 12:00:00 AM  07/24/2020 12:00:00 AM      2130
# 74771  200306227        02-07-2020 00:00        02-06-2020 00:00      1800
# 74772  201009534  05/29/2020 12:00:00 AM  05/26/2020 12:00:00 AM       810
#
#        AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 74768    10  West Valley         1011         1     330
# 74769    11    Northeast         1123         2     624
# 74770     8      West LA          855         1     310
# 74771     3    Southwest          397         1     510
# 74772    10  West Valley         1078         2     956
#
#                                    Crm Cd Desc  ... Status  Status Desc  \
# 74768                    BURGLARY FROM VEHICLE  ...     IC  Invest Cont
# 74769                 BATTERY - SIMPLE ASSAULT  ...     IC  Invest Cont
# 74770                                 BURGLARY  ...     IC  Invest Cont
# 74771                         VEHICLE - STOLEN  ...     IC  Invest Cont
# 74772  LETTERS, LEWD  -  TELEPHONE CALLS, LEWD  ...     AO  Adult Other
#
#       Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 74768    330.0      NaN       NaN      NaN
# 74769    624.0      NaN       NaN      NaN
# 74770    310.0      NaN       NaN      NaN
# 74771    510.0      NaN       NaN      NaN
# 74772    956.0      NaN       NaN      NaN
#
#                                        LOCATION Cross Street      LAT  \
# 74768  18900    SHERMAN                      WY          NaN  34.2047
# 74769   3200    GLENDALE                     BL          NaN  34.1207
# 74770   1400    GREENFIELD                   AV          NaN  34.0519
# 74771           43RD                         ST        MENLO  34.0073
# 74772   4900    BALBOA                       BL          NaN  34.1593
#
#             LON
# 74768 -118.5531
# 74769 -118.2641
# 74770 -118.4441
# 74771 -118.2980
# 74772  -11.0000
#
# [5 rows x 28 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74773 entries, 0 to 74772
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DR_NO           74773 non-null  int64
#  1   Date Rptd       74773 non-null  object
#  2   DATE OCC        74773 non-null  object
#  3   TIME OCC        74773 non-null  int64
#  4   AREA            74773 non-null  int64
#  5   AREA NAME       74773 non-null  object
#  6   Rpt Dist No     74773 non-null  int64
#  7   Part 1-2        74773 non-null  int64
#  8   Crm Cd          74773 non-null  int64
#  9   Crm Cd Desc     74773 non-null  object
#  10  Mocodes         65287 non-null  object
#  11  Vict Age        74773 non-null  int64
#  12  Vict Sex        65607 non-null  object
#  13  Vict Descent    65605 non-null  object
#  14  Premis Cd       74772 non-null  float64
#  15  Premis Desc     74739 non-null  object
#  16  Weapon Used Cd  28372 non-null  float64
#  17  Weapon Desc     28372 non-null  object
#  18  Status          74773 non-null  object
#  19  Status Desc     74773 non-null  object
#  20  Crm Cd 1        74771 non-null  float64
#  21  Crm Cd 2        6026 non-null   float64
#  22  Crm Cd 3        195 non-null    float64
#  23  Crm Cd 4        9 non-null      float64
#  24  LOCATION        74773 non-null  object
#  25  Cross Street    14138 non-null  object
#  26  LAT             74773 non-null  float64
#  27  LON             74773 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 16.0+ MB
# None
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  7.477300e+04  74773.000000  74773.000000  74773.000000  74773.000000
# mean   2.006719e+08   1354.674120      6.657898    711.345379      1.414053
# std    1.078812e+06    651.256483      3.697911    368.190532      0.492561
# min    8.170000e+02      1.000000      1.000000    101.000000      1.000000
# 25%    2.003190e+08    920.000000      3.000000    392.000000      1.000000
# 50%    2.007050e+08   1440.000000      7.000000    702.000000      1.000000
# 75%    2.010090e+08   1900.000000     10.000000   1025.000000      2.000000
# max    2.013099e+08   2359.000000     20.000000   2062.000000      2.000000
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  74773.000000  74773.000000  74772.000000    28372.000000  74771.000000
# mean     511.081741     30.008265    292.215027      364.017975    510.763665
# std      211.809796     21.652466    213.561280      122.868607    211.535417
# min      110.000000      0.000000    101.000000      101.000000    110.000000
# 25%      330.000000     13.000000    101.000000      310.000000    330.000000
# 50%      510.000000     31.000000    203.000000      400.000000    510.000000
# 75%      627.000000     45.000000    501.000000      400.000000    627.000000
# max      956.000000     99.000000    974.000000      516.000000    956.000000
#
#           Crm Cd 2    Crm Cd 3    Crm Cd 4           LAT           LON
# count  6026.000000  195.000000    9.000000  74773.000000  74773.000000
# mean    956.489047  985.112821  990.444444     33.931531   -117.924960
# std     113.144021   43.002608   22.666667      1.975646      6.869349
# min     220.000000  740.000000  930.000000      0.000000   -118.571300
# 25%     998.000000  998.000000  998.000000     34.017300   -118.362600
# 50%     998.000000  998.000000  998.000000     34.051100   -118.301200
# 75%     998.000000  998.000000  998.000000     34.098000   -118.264300
# max     999.000000  998.000000  998.000000     34.236700      0.000000
# DR_NO                 0
# Date Rptd             0
# DATE OCC              0
# TIME OCC              0
# AREA                  0
# AREA NAME             0
# Rpt Dist No           0
# Part 1-2              0
# Crm Cd                0
# Crm Cd Desc           0
# Mocodes            9486
# Vict Age              0
# Vict Sex           9166
# Vict Descent       9168
# Premis Cd             1
# Premis Desc          34
# Weapon Used Cd    46401
# Weapon Desc       46401
# Status                0
# Status Desc           0
# Crm Cd 1              2
# Crm Cd 2          68747
# Crm Cd 3          74578
# Crm Cd 4          74764
# LOCATION              0
# Cross Street      60635
# LAT                   0
# LON                   0
# dtype: int64
# DR_NO             2.013099e+08
# TIME OCC          2.359000e+03
# AREA              2.000000e+01
# Rpt Dist No       2.062000e+03
# Part 1-2          2.000000e+00
# Crm Cd            9.560000e+02
# Vict Age          9.900000e+01
# Premis Cd         9.740000e+02
# Weapon Used Cd    5.160000e+02
# Crm Cd 1          9.560000e+02
# Crm Cd 2          9.990000e+02
# Crm Cd 3          9.980000e+02
# Crm Cd 4          9.980000e+02
# LAT               3.423670e+01
# LON               0.000000e+00
# dtype: float64
# DR_NO             817.0000
# TIME OCC            1.0000
# AREA                1.0000
# Rpt Dist No       101.0000
# Part 1-2            1.0000
# Crm Cd            110.0000
# Vict Age            0.0000
# Premis Cd         101.0000
# Weapon Used Cd    101.0000
# Crm Cd 1          110.0000
# Crm Cd 2          220.0000
# Crm Cd 3          740.0000
# Crm Cd 4          930.0000
# LAT                 0.0000
# LON              -118.5713
# dtype: float64
# DR_NO             2.006719e+08
# TIME OCC          1.354674e+03
# AREA              6.657898e+00
# Rpt Dist No       7.113454e+02
# Part 1-2          1.414053e+00
# Crm Cd            5.110817e+02
# Vict Age          3.000827e+01
# Premis Cd         2.922150e+02
# Weapon Used Cd    3.640180e+02
# Crm Cd 1          5.107637e+02
# Crm Cd 2          9.564890e+02
# Crm Cd 3          9.851128e+02
# Crm Cd 4          9.904444e+02
# LAT               3.393153e+01
# LON              -1.179250e+02
# dtype: float64
# DR_NO             2.007050e+08
# TIME OCC          1.440000e+03
# AREA              7.000000e+00
# Rpt Dist No       7.020000e+02
# Part 1-2          1.000000e+00
# Crm Cd            5.100000e+02
# Vict Age          3.100000e+01
# Premis Cd         2.030000e+02
# Weapon Used Cd    4.000000e+02
# Crm Cd 1          5.100000e+02
# Crm Cd 2          9.980000e+02
# Crm Cd 3          9.980000e+02
# Crm Cd 4          9.980000e+02
# LAT               3.405110e+01
# LON              -1.183012e+02
# dtype: float64
#            DR_NO         Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0            817  03-02-2020 00:00  05/30/2020 12:00:00 AM    1200.0  12.0
# 1       10304468               NaN                     NaN       NaN   NaN
# 2      190101086               NaN                     NaN       NaN   NaN
# 3      190326475               NaN                     NaN       NaN   NaN
# 4      191501505               NaN                     NaN       NaN   NaN
# ...          ...               ...                     ...       ...   ...
# 74768  201309931               NaN                     NaN       NaN   NaN
# 74769  201309934               NaN                     NaN       NaN   NaN
# 74770  201309935               NaN                     NaN       NaN   NaN
# 74771  201309936               NaN                     NaN       NaN   NaN
# 74772  201309937               NaN                     NaN       NaN   NaN
#
#          AREA NAME  Rpt Dist No  Part 1-2  Crm Cd       Crm Cd Desc  ...  \
# 0      77th Street        162.0       1.0   510.0  VEHICLE - STOLEN  ...
# 1              NaN          NaN       NaN     NaN               NaN  ...
# 2              NaN          NaN       NaN     NaN               NaN  ...
# 3              NaN          NaN       NaN     NaN               NaN  ...
# 4              NaN          NaN       NaN     NaN               NaN  ...
# ...            ...          ...       ...     ...               ...  ...
# 74768          NaN          NaN       NaN     NaN               NaN  ...
# 74769          NaN          NaN       NaN     NaN               NaN  ...
# 74770          NaN          NaN       NaN     NaN               NaN  ...
# 74771          NaN          NaN       NaN     NaN               NaN  ...
# 74772          NaN          NaN       NaN     NaN               NaN  ...
#
#       Status  Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0         IC  Invest Cont    510.0    998.0     998.0    998.0
# 1        NaN          NaN      NaN      NaN       NaN      NaN
# 2        NaN          NaN      NaN      NaN       NaN      NaN
# 3        NaN          NaN      NaN      NaN       NaN      NaN
# 4        NaN          NaN      NaN      NaN       NaN      NaN
# ...      ...          ...      ...      ...       ...      ...
# 74768    NaN          NaN      NaN      NaN       NaN      NaN
# 74769    NaN          NaN      NaN      NaN       NaN      NaN
# 74770    NaN          NaN      NaN      NaN       NaN      NaN
# 74771    NaN          NaN      NaN      NaN       NaN      NaN
# 74772    NaN          NaN      NaN      NaN       NaN      NaN
#
#                                      LOCATION Cross Street      LAT       LON
# 0                                         7TH     BROADWAY  34.1016 -118.2827
# 1      800 N  ALAMEDA                      ST          NaN      NaN       NaN
# 2                                         NaN          NaN      NaN       NaN
# 3                                         NaN          NaN      NaN       NaN
# 4                                         NaN          NaN      NaN       NaN
# ...                                       ...          ...      ...       ...
# 74768                                     NaN          NaN      NaN       NaN
# 74769                                     NaN          NaN      NaN       NaN
# 74770                                     NaN          NaN      NaN       NaN
# 74771                                     NaN          NaN      NaN       NaN
# 74772                                     NaN          NaN      NaN       NaN
#
# [74773 rows x 28 columns]
# DR_NO             74773
# Date Rptd         74773
# DATE OCC          74773
# TIME OCC          74773
# AREA              74773
# AREA NAME         74773
# Rpt Dist No       74773
# Part 1-2          74773
# Crm Cd            74773
# Crm Cd Desc       74773
# Mocodes           65287
# Vict Age          74773
# Vict Sex          65607
# Vict Descent      65605
# Premis Cd         74772
# Premis Desc       74739
# Weapon Used Cd    28372
# Weapon Desc       28372
# Status            74773
# Status Desc       74773
# Crm Cd 1          74771
# Crm Cd 2           6026
# Crm Cd 3            195
# Crm Cd 4              9
# LOCATION          74773
# Cross Street      14138
# LAT               74773
# LON               74773
# dtype: int64
# [761]
#            DR_NO         Date Rptd          DATE OCC  TIME OCC  AREA  \
# 49176  200613424  08-02-2020 00:00  08-02-2020 00:00      2030     6
#
#        AREA NAME  Rpt Dist No  Part 1-2  Crm Cd      Crm Cd Desc  ... Status  \
# 49176  Hollywood          657         1     761  BRANDISH WEAPON  ...     AO
#
#        Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  LOCATION  \
# 49176  Adult Other    761.0    920.0     930.0    998.0   WESTERN
#
#       Cross Street      LAT       LON
# 49176      ROMAINE  34.0885 -118.3092
#
# [1 rows x 28 columns]
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <ipython-input-6-fc6db5a2f71f>:116: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df["Crm Cd"], shade=True)
